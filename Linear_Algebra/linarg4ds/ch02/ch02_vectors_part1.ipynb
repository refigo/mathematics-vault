# %% [markdown]
# Chapter 2: Vectors Part 1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# optional: these lines define global figure properties used for publication.
import matplotlib_inline.backend_inline
matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
plt.rcParams.update({'font.size':14})

# %% [markdown]
# ### Creating vectors

# %%
# a vector as a Python list datatype
asList = [1,2,3]

# same numbers, but as a dimensionless numpy array
asArray = np.array([1,2,3])

# again same numbers, but now endowed with orientations
rowVec = np.array([ [1,2,3] ]) # row
colVec = np.array([ [1],[2],[3] ]) # column

# Note the use of spacing when defining the vectors; that is not necessary but makes the code more readable.

# %%
# Check the sizes of the variables
print(f'asList:  {np.shape(asList)}') # using np's shape function
print(f'asArray: {asArray.shape}') # using a method associated with numpy objects
print(f'rowVec:  {rowVec.shape}')
print(f'colVec:  {colVec.shape}')
# Out:
# asList:  (3,)
# asArray: (3,)
# rowVec:  (1, 3)
# colVec:  (3, 1)

# %% [markdown]
# ### Geometry of vectors

# %%
# create a vector
v = np.array([-1,2])

# plot the vector (and a dot for the tail)
plt.arrow(0,0,v[0],v[1],head_width=.5,width=.1)
plt.plot(0,0,'ko',markerfacecolor='k',markersize=7)

# add axis lines
plt.plot([-3,3],[0,0],'--',color=[.8,.8,.8],zorder=-1)
plt.plot([0,0],[-3,3],'--',color=[.8,.8,.8],zorder=-1)

# make the plot look nicer
plt.axis('square')
plt.axis([-3,3,-3,3])
plt.xlabel('v_0')
plt.ylabel('v_1')
plt.title('Vector v in standard position')
plt.show()

# %%
# A range of starting positions

startPos = [
            [0,0],
            [-1,-1],
            [1.5,-2.5],
            ]

# create a new figure
fig = plt.figure(figsize=(6,6))

for s in startPos:
    
    # plot that vector (and a dot for the tail)
    # note that plt.arrow automatically adds an offset to the third/fourth inputs
    plt.arrow(s[0],s[1],v[0],v[1],head_width=.5,width=.1,color='black')
    plt.plot(s[0],s[1],'ko',markerfacecolor='k',markersize=7)

    # indicate the vector in its standard position
    if s==[0,0]:
        plt.text(v[0]+.1,v[1]+.2,'"Standard pos."')

# add axis lines
plt.plot([-3,3],[0,0],'--',color=[.8,.8,.8],zorder=-1)
plt.plot([0,0],[-3,3],'--',color=[.8,.8,.8],zorder=-1)

# make the plot look nicer
plt.axis('square')
plt.axis([-3,3,-3,3])
plt.xlabel('v_0')
plt.ylabel('v_1')
plt.title('Vectors v in various locations')
# plt.savefig('Figure_02_01.png',dpi=300) # write out the fig to a file
plt.show()

# %% [markdown]
# ### Adding vectors

# %%
# Using 2D vectors here instead of 3D vectors in the book to facilitate visualization
v = np.array([1,2])
w = np.array([4,-6])
vPlusW = v+w

# print out all three vectors
print(v)
print(w)
print(vPlusW)

# Note that here we don't need to worry about vector orientation (row vs. column)
# so for simplicity the vectors are created orientationless.
# Out:
# [1 2]
# [ 4 -6]
# [ 5 -4]

# %% [markdown]
# ### Substracting vectors

# %%
# Same v and w as above for comparison
vMinusW = v-w

# print out all three vectors
print(v)
print(w)
print(vMinusW)
# Out:
# [1 2]
# [ 4 -6]
# [-3  8]

# %% [markdown]
# ### Vector-scalar multiplication

# %%
# a scalar
s = -1/2

# a vactor
b = np.array([3,4])

# print them
print(b*s)

# Question: Does vector b need to be a numpy array? What happens if it's a list?
test_b = [3,4]
# print(test_b*s)
# Answer: TypeError: can't multiply sequence by non-int of type 'float'

# Question: What happens if we try to multiply a vector by a scalar that is not a float?
test_s = 2
print(test_b*test_s)
# Answer: No error, but the result is not what we expect.
# Out:
# [-1.5 -2. ]
# [3, 4, 3, 4]

# %%
# Scalar-vector addition
s = 3.5

print(v)
print(s+v)
# Out:
# [1 2]
# [4.5 5.5]

# %%
# plot
plt.plot([0,b[0]],[0,b[1]],'m--',linewidth=3,label='b')
plt.plot([0,s*b[0]],[0,s*b[1]],'k:',linewidth=3,label='sb')

plt.grid()
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.legend()
plt.show()

# %%
# Effects of different scalars

# a list of scalars:
scalars = [ 1, 2, 1/3, 0, -2/3 ]

baseVector = np.array([ .75,1 ])

# create a figure
fig,axs = plt.subplots(1,len(scalars),figsize=(12,3))
i = 0 # axis counter

for s in scalars:

    # compute the scaled vector
    v = s*baseVector

    # plot it
    axs[i].arrow(0,0,baseVector[0],baseVector[1],head_width=.3,width=.1,color='k',length_includes_head=True)
    axs[i].arrow(.1,0,v[0],v[1],head_width=.3,width=.1,color=[.75,.75,.75],length_includes_head=True)
    axs[i].grid(linestyle='--')
    axs[i].axis('square')
    axs[i].axis([-2.5,2.5,-2.5,2.5])
    axs[i].set(xticks=np.arange(-2,3), yticks=np.arange(-2,3))
    axs[i].set_title(r'$\sigma$' + ' = ' + f'{s:.2f}')
    i+=1 # update axis counter

plt.tight_layout()
# plt.savefig('Figure_02_03.png',dpi=300)
plt.show()

# %% [markdown]
# ### Vector transpose

# %%
# Row vector
r = np.array([ [1,2,3]])

# orientationless array
l = np.array([1,2,3])

# %%
# print out the vector, its transpose, and its double-transpose
print(r), print(' ')

# Transpose the row vector
print(r.T), print(' ')

# double-transpose
print(r.T.T)
# Out:
# [[1 2 3]]
#
# [[1]
#  [2]
#  [3]]
#
# [[1 2 3]]

# %%
# Same for the orientationless array
print(l), print(' ')
print(l.T), print(' ')
print(l.T.T)
# Out:
# [1 2 3]
#
# [1 2 3]
#
# [1 2 3]

# %% [markdown]
# ### The dot product is distributive

# %%
# just some random vectors...
v = np.array([ 0,1,2 ])
w = np.array([ 3,5,8 ])
u = np.array([ 13,21,34 ])

# two ways to compute
res1 = np.dot( v, w+u )
res2 = np.dot( v,w ) + np.dot( v,u )

# show that they are equivalent
res1,res2
# Out:
# (110, 110)

# %% [markdown]
# ### Exercise 1

# %%
# The vectors
v = np.array([1,2])
w = np.array([4,-6])
vPlusW = v+w


# now plot all three vectors
plt.figure(figsize=(6,6))

a1 = plt.arrow(0,0,v[0],v[1],head_width=.3,width=.1,color='blue',length_includes_head=True)
a2 = plt.arrow(v[0],v[1],w[0],w[1],head_width=.3,width=.1,color='red',length_includes_head=True)
a3 = plt.arrow(0,0,vPlusW[0],vPlusW[1],head_width=.3,width=.1,color='green',length_includes_head=True)


# make the plot look a bit nicer
plt.grid(linestyle='--',linewidth=.5)
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.legend([a1,a2,a3],['v','w','v+w'])
plt.title(r'Vectors $\vec{v}, \vec{w}$, and $\vec{v}+\vec{w}$')
# plt.savefig('Figure_02_02a.png',dpi=300)
plt.show()

# %%
# vector difference
vMinusW = v-w


# now plot all three vectors
plt.figure(figsize=(6,6))

a1 = plt.arrow(0,0,v[0],v[1],head_width=.3,width=.1,color='k',length_includes_head=True)
a2 = plt.arrow(0,0,w[0],w[1],head_width=.3,width=.1,color=[.5,.5,.5],length_includes_head=True)
a3 = plt.arrow(w[0],w[1],vMinusW[0],vMinusW[1],head_width=.3,width=.1,color=[.8,.8,.8],length_includes_head=True)


# make the plot look a bit nicer
plt.grid(linestyle='--',linewidth=.5)
plt.axis('square')
plt.axis([-6,6,-6,6])
plt.legend([a1,a2,a3],['v','w','v-w'])
plt.title(r'Vectors $\vec{v}, \vec{w}$, and $\vec{v}-\vec{w}$')
# plt.savefig('Figure_02_02b.png',dpi=300)
plt.show()

# %% [markdown]
# ### Exercise 2

# %%
# the function
def normOfVect(v):
    return np.sqrt(np.sum(v**2))

# test it on a unit-norm vector
w = np.array([0,0,1])
print( normOfVect(w) )

# non-unit-norm vector, and confirm using np.linalg.norm
w = np.array([1,2,3])
print( normOfVect(w) )
print( np.linalg.norm(w) )
# Out:
# 1.0
# 3.7416573867739413
# 3.7416573867739413

# %% [markdown]
# ### Exercise 3

# %%
# define function
def createUnitVector(v):
    mu = np.linalg.norm(v)
    return v / mu


# test on a unit vector
w = np.array([0,1,0])
print( createUnitVector(w) )

# test on a non-unit vector that is easy to confirm
w = np.array([0,3,0])
print( createUnitVector(w))

# test on a non-unit vector
w = np.array([13,-5,7])
uw = createUnitVector(w)
print( uw ), print(' ')
# confirm the vectors' norms
print( np.linalg.norm(w),np.linalg.norm(uw) )

# what happens with the zeros vector?
print('\n\n\n') # just some spaces
createUnitVector( np.zeros((4,1)) )
# Out:
# [0. 1. 0.]
# [0. 1. 0.]
# [ 0.83395039 -0.32075015  0.44905021]
#
# 15.588457268119896 0.9999999999999999
# /tmp/ipykernel_31556/2111834077.py:4: RuntimeWarning: invalid value encountered in divide
#   return v / mu
# array([[nan],
#        [nan],
#        [nan],
#        [nan]])

# %% [markdown]
# ### Exercise 4

# %%
# mine
def createScaledVector(v, size):
    uv = v / np.linalg.norm(v)
    return uv * size

# test
v = np.array([1,2,3])
print(v)
print(createScaledVector(v, 1))
print(createScaledVector(v, 2))
print(createScaledVector(v, 4))
# Out:
# [1 2 3]
# [0.26726124 0.53452248 0.80178373]
# [0.53452248 1.06904497 1.60356745]
# [1.06904497 2.13808994 3.2071349 ]

# %%
# define the functon
def createMagVector(v,mag):
    mu = np.linalg.norm(v)
    return mag * v / mu

# test on a vector that is easy to confirm
w = np.array([1,0,0])
mw = createMagVector(w,4)
print( mw )

# confirm the vectors' norms
print( np.linalg.norm(w),np.linalg.norm(mw) )
# Out:
# [4. 0. 0.]
# 1.0 4.0

# %% [markdown]
# ### Exercise 5

# %%
# the row vector to transpose
v = np.array([ [1,2,3] ])

# the column vector to transpose
vt = np.zeros((3,1))

print(v.shape[1])

# direct implementation of the formula using a for loop
for i in range(v.shape[1]):
    vt[i][0] = v[0][i]

# confirm!
print(v), print(' ')
print(vt)

# Note about data types: The two vectors actually have different data types
#  (ints vs. floats). That happened because I defined v using ints while the default type
#  for np.zeros is float. You can match data types in several ways, including: 
#  (1) write 3. instead of 3 when creating v;
#  (deprecated) (2) use dtype=np.float as an optional input.
# Out:
# 3
# [[1 2 3]]
#
# [[1.]
#  [2.]
#  [3.]]

# %%
v = np.array([ [1,2,3] ], dtype=np.float)

print(v)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 v = np.array([ [1,2,3] ], dtype=np.float)
#       3 print(v)
#
# File ~/.local/lib/python3.10/site-packages/numpy/__init__.py:324, in __getattr__(attr)
#     319     warnings.warn(
#     320         f"In the future `np.{attr}` will be defined as the "
#     321         "corresponding NumPy scalar.", FutureWarning, stacklevel=2)
#     323 if attr in __former_attrs__:
# --> 324     raise AttributeError(__former_attrs__[attr])
#     326 if attr == 'testing':
#     327     import numpy.testing as testing
#
# AttributeError: module 'numpy' has no attribute 'float'.
# `np.float` was a deprecated alias for the builtin `float`. To avoid this error in existing code, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# The aliases was originally deprecated in NumPy 1.20; for more details and guidance see the original release note at:
#     https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %% [markdown]
# ### Exercise 6

# %%
# mine
v = np.array([ [1,2,3] ])

mu = np.dot(v,v.T)
print(mu)
# Out:
# [[14]]

# %%
# some vector
c = np.random.randn(5)
print(c)

# squared norm as dot product with itself
sqrNrm1 = np.dot(c,c)

# squared norm via our function from exercise 2
sqrNrm2 = normOfVect(c)**2

# print both to confirm they're the same
print(sqrNrm1,sqrNrm2)
# Out:
# [ 0.77506232 -0.47746333  0.89546524 -0.3053545   1.12294758]
# 2.9848034745684475 2.9848034745684475

# %% [markdown]
# ### Exercise 7

# %%
# dimensionality
n = 11

# some random column vectors
a = np.random.randn(n,1)
b = np.random.randn(n,1)
# print(a)
# print(b)

# dot products both ways
atb = np.sum(a*b)
bta = np.sum(b*a)
# print(atb)
# print(bta)

# they're equal if their difference is zero
print(atb-bta)

# For an extra challenge, see what happens when you use np.dot() to compute the dot products.
# Out:
# 0.0

# %%
atb = np.sum(np.dot(a,b))
bta = np.sum(np.dot(b,a))
print(atb)
print(bta)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 atb = np.sum(np.dot(a,b))
#       2 bta = np.sum(np.dot(b,a))
#       3 print(atb)
#
# ValueError: shapes (11,1) and (11,1) not aligned: 1 (dim 1) != 11 (dim 0)
